# %% [markdown]
# <a href="https://colab.research.google.com/github/mitkrieg/citibike-timeseries/blob/main/var_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from fbprophet import Prophet
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/Flatiron/Capstone/
# %ls
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/Flatiron/Capstone
# 'Citibike Re-Balancing.gslides'   fbprophet_model.ipynb   starts.pickle
#  cleaning.py                      historical.pickle       station_mat.pickle
#  data/                            live.pickle             station.py
#  ends.pickle                      __pycache__/            trips.pickle

# %%
year_2018 = pickle.load(open('/gdrive/MyDrive/Flatiron/Capstone/historical.pickle','rb'))

# %%
station_mat = year_2018.avail_bikes.swaplevel().unstack().resample('H').mean()

# %%
sns.heatmap(station_mat.isnull(),cbar=False)

# %%
station_mat = station_mat.interpolate()
sns.heatmap(station_mat.isnull(),cbar=False)

# %%
station_drop = list(station_mat.isna().sum().sort_values(ascending=False).head(45).index)
station_mat.drop(columns=station_drop,inplace=True)

# %%
sns.heatmap(station_mat.isnull(),cbar=False)

# %%
station_mat.columns = [str(col) for col in station_mat.columns]
station_mat.head()
# Out:
#                        72   79   82    83  116  ...  3491  3492  3493  3494  3495
# date_time                                       ...
# 2018-01-01 00:00:00  13.0  4.0  3.0  30.0  0.0  ...  13.0  16.0  11.0  17.0  20.0
# 2018-01-01 01:00:00  13.0  4.0  4.0  30.0  0.0  ...  13.0  16.0  11.0  17.0  20.0
# 2018-01-01 02:00:00  13.0  4.0  4.0  30.0  0.0  ...  13.0  16.0  11.0  17.0  20.0
# 2018-01-01 03:00:00  13.0  4.0  4.0  30.0  0.0  ...  13.0  16.0  11.5  17.0  20.0
# 2018-01-01 04:00:00  13.0  4.0  4.0  30.0  0.0  ...  13.0  16.0  12.0  17.0  20.0
#
# [5 rows x 664 columns]

# %%
import statsmodels as sm
from statsmodels.tsa import vector_ar
from statsmodels.tsa.stattools import adfuller
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
def dickey_fuller(ts):
        dftest = adfuller(ts)

        # Extract and display test results
        dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
        for key,value in dftest[4].items():
            dfoutput['Critical Value (%s)'%key] = value
    
        print ('Dickey-Fuller test: \n')
        print(dfoutput)
        
        if dfoutput['p-value'] < .05:
            print(f'\nStationary: p-value {dfoutput["p-value"]} < 0.05\n')
            return True
        else:
           print(f'\nNot Stationary: p-value {dfoutput["p-value"]} > 0.05\n')
           return False

# %%
dickey_results = pd.Series()
for col in station_mat.columns:
  print("Station: ",col)
  dftest = dickey_fuller(station_mat[col])
  dickey_results[col] = dftest
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# Station:  72
# Dickey-Fuller test:
#
# Test Statistic                -1.007571e+01
# p-value                        1.225422e-17
# #Lags Used                     2.800000e+01
# Number of Observations Used    8.731000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.2254223457369034e-17 < 0.05
#
# Station:  79
# Dickey-Fuller test:
#
# Test Statistic                -8.187918e+00
# p-value                        7.808508e-13
# #Lags Used                     3.300000e+01
# Number of Observations Used    8.726000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 7.80850809226222e-13 < 0.05
#
# Station:  82
# Dickey-Fuller test:
#
# Test Statistic                   -4.937420
# p-value                           0.000029
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 2.9473909703243077e-05 < 0.05
#
# Station:  83
# Dickey-Fuller test:
#
# Test Statistic                   -4.314734
# p-value                           0.000419
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.0004188268269610069 < 0.05
#
# Station:  116
# /usr/local/lib/python3.6/dist-packages/statsmodels/regression/linear_model.py:867: RuntimeWarning:
#
# divide by zero encountered in log
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:1294: RuntimeWarning:
#
# invalid value encountered in true_divide
# Streaming output truncated to the last 5000 lines.
# Stationary: p-value 4.154070897302179e-11 < 0.05
#
# Station:  3056
# Dickey-Fuller test:
#
# Test Statistic                -6.644211e+00
# p-value                        5.315843e-09
# #Lags Used                     1.700000e+01
# Number of Observations Used    8.742000e+03
# Critical Value (1%)           -3.431098e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.315842805961496e-09 < 0.05
#
# Station:  3057
# Dickey-Fuller test:
#
# Test Statistic                -8.834440e+00
# p-value                        1.734423e-14
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.7344231172322816e-14 < 0.05
#
# Station:  3058
# Dickey-Fuller test:
#
# Test Statistic                -7.639489e+00
# p-value                        1.912735e-11
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.9127352335647206e-11 < 0.05
#
# Station:  3059
# Dickey-Fuller test:
#
# Test Statistic                -7.330399e+00
# p-value                        1.131828e-10
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.1318283483005994e-10 < 0.05
#
# Station:  3060
# Dickey-Fuller test:
#
# Test Statistic                -6.609210e+00
# p-value                        6.440338e-09
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.723000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 6.440337813089483e-09 < 0.05
#
# Station:  3061
# Dickey-Fuller test:
#
# Test Statistic                -5.931325e+00
# p-value                        2.376816e-07
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.3768162900172514e-07 < 0.05
#
# Station:  3062
# Dickey-Fuller test:
#
# Test Statistic                -6.491089e+00
# p-value                        1.226164e-08
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.226163841039918e-08 < 0.05
#
# Station:  3063
# Dickey-Fuller test:
#
# Test Statistic                -6.461525e+00
# p-value                        1.439261e-08
# #Lags Used                     2.900000e+01
# Number of Observations Used    8.730000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.4392611356995138e-08 < 0.05
#
# Station:  3064
# Dickey-Fuller test:
#
# Test Statistic                -8.879054e+00
# p-value                        1.333276e-14
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.3332756119148741e-14 < 0.05
#
# Station:  3065
# Dickey-Fuller test:
#
# Test Statistic                   -4.389768
# p-value                           0.000309
# #Lags Used                       24.000000
# Number of Observations Used    8735.000000
# Critical Value (1%)              -3.431099
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.00030945726245191926 < 0.05
#
# Station:  3066
# Dickey-Fuller test:
#
# Test Statistic                -7.443917e+00
# p-value                        5.906548e-11
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.723000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.906547575589012e-11 < 0.05
#
# Station:  3067
# Dickey-Fuller test:
#
# Test Statistic                   -5.034231
# p-value                           0.000019
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 1.897949653609338e-05 < 0.05
#
# Station:  3068
# Dickey-Fuller test:
#
# Test Statistic                -6.591695e+00
# p-value                        7.088155e-09
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 7.088155483540671e-09 < 0.05
#
# Station:  3069
# Dickey-Fuller test:
#
# Test Statistic                   -5.161614
# p-value                           0.000011
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 1.0525297594166595e-05 < 0.05
#
# Station:  3070
# Dickey-Fuller test:
#
# Test Statistic                   -5.334142
# p-value                           0.000005
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 4.6509769752954816e-06 < 0.05
#
# Station:  3071
# Dickey-Fuller test:
#
# Test Statistic                -7.059451e+00
# p-value                        5.269923e-10
# #Lags Used                     3.300000e+01
# Number of Observations Used    8.726000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.269923439874195e-10 < 0.05
#
# Station:  3072
# Dickey-Fuller test:
#
# Test Statistic                   -5.444933
# p-value                           0.000003
# #Lags Used                       25.000000
# Number of Observations Used    8734.000000
# Critical Value (1%)              -3.431099
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 2.723840735218143e-06 < 0.05
#
# Station:  3073
# Dickey-Fuller test:
#
# Test Statistic                   -4.160149
# p-value                           0.000769
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.000769066765806551 < 0.05
#
# Station:  3074
# Dickey-Fuller test:
#
# Test Statistic                -5.749191e+00
# p-value                        6.021729e-07
# #Lags Used                     3.200000e+01
# Number of Observations Used    8.727000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 6.021729423269088e-07 < 0.05
#
# Station:  3075
# Dickey-Fuller test:
#
# Test Statistic                -7.026643e+00
# p-value                        6.339392e-10
# #Lags Used                     9.000000e+00
# Number of Observations Used    8.750000e+03
# Critical Value (1%)           -3.431098e+00
# Critical Value (5%)           -2.861870e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 6.33939197287428e-10 < 0.05
#
# Station:  3076
# Dickey-Fuller test:
#
# Test Statistic                -7.410092e+00
# p-value                        7.172008e-11
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 7.17200785729377e-11 < 0.05
#
# Station:  3077
# Dickey-Fuller test:
#
# Test Statistic                -8.395043e+00
# p-value                        2.311220e-13
# #Lags Used                     2.800000e+01
# Number of Observations Used    8.731000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.311220234107312e-13 < 0.05
#
# Station:  3078
# Dickey-Fuller test:
#
# Test Statistic                -8.671123e+00
# p-value                        4.543473e-14
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.543473300634889e-14 < 0.05
#
# Station:  3080
# Dickey-Fuller test:
#
# Test Statistic                -8.745863e+00
# p-value                        2.924076e-14
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.9240755831354696e-14 < 0.05
#
# Station:  3081
# Dickey-Fuller test:
#
# Test Statistic                -6.347808e+00
# p-value                        2.656204e-08
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.6562039601793056e-08 < 0.05
#
# Station:  3082
# Dickey-Fuller test:
#
# Test Statistic                -7.848955e+00
# p-value                        5.668784e-12
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.668784493469869e-12 < 0.05
#
# Station:  3083
# Dickey-Fuller test:
#
# Test Statistic                -6.205508e+00
# p-value                        5.670741e-08
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.670740946775073e-08 < 0.05
#
# Station:  3085
# Dickey-Fuller test:
#
# Test Statistic                   -5.637530
# p-value                           0.000001
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 1.054689792613297e-06 < 0.05
#
# Station:  3086
# Dickey-Fuller test:
#
# Test Statistic                -9.894842e+00
# p-value                        3.479994e-17
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.479994194563753e-17 < 0.05
#
# Station:  3087
# Dickey-Fuller test:
#
# Test Statistic                -6.834173e+00
# p-value                        1.860724e-09
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.8607236479296336e-09 < 0.05
#
# Station:  3088
# Dickey-Fuller test:
#
# Test Statistic                -6.869677e+00
# p-value                        1.526987e-09
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.526986815491287e-09 < 0.05
#
# Station:  3090
# Dickey-Fuller test:
#
# Test Statistic                -8.929216e+00
# p-value                        9.919730e-15
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 9.919729974787833e-15 < 0.05
#
# Station:  3091
# Dickey-Fuller test:
#
# Test Statistic                -6.011714e+00
# p-value                        1.567763e-07
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.567762780533763e-07 < 0.05
#
# Station:  3092
# Dickey-Fuller test:
#
# Test Statistic                -1.030547e+01
# p-value                        3.287636e-18
# #Lags Used                     3.000000e+01
# Number of Observations Used    8.729000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.2876363541661013e-18 < 0.05
#
# Station:  3093
# Dickey-Fuller test:
#
# Test Statistic                -1.055996e+01
# p-value                        7.774409e-19
# #Lags Used                     2.700000e+01
# Number of Observations Used    8.732000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 7.774408895751918e-19 < 0.05
#
# Station:  3094
# Dickey-Fuller test:
#
# Test Statistic                -7.281423e+00
# p-value                        1.496909e-10
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.4969091226737387e-10 < 0.05
#
# Station:  3095
# Dickey-Fuller test:
#
# Test Statistic                -7.987757e+00
# p-value                        2.522048e-12
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.5220478033577475e-12 < 0.05
#
# Station:  3096
# Dickey-Fuller test:
#
# Test Statistic                   -5.470009
# p-value                           0.000002
# #Lags Used                       34.000000
# Number of Observations Used    8725.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 2.410497360706026e-06 < 0.05
#
# Station:  3100
# Dickey-Fuller test:
#
# Test Statistic                -8.310440e+00
# p-value                        3.801771e-13
# #Lags Used                     3.300000e+01
# Number of Observations Used    8.726000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.801771391416511e-13 < 0.05
#
# Station:  3101
# Dickey-Fuller test:
#
# Test Statistic                -7.504241e+00
# p-value                        4.175300e-11
# #Lags Used                     3.000000e+01
# Number of Observations Used    8.729000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.1752997179799735e-11 < 0.05
#
# Station:  3102
# Dickey-Fuller test:
#
# Test Statistic                -7.239710e+00
# p-value                        1.898382e-10
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.8983821559841445e-10 < 0.05
#
# Station:  3103
# Dickey-Fuller test:
#
# Test Statistic                   -3.199105
# p-value                           0.020037
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.020036571639894276 < 0.05
#
# Station:  3105
# Dickey-Fuller test:
#
# Test Statistic                -6.581492e+00
# p-value                        7.494698e-09
# #Lags Used                     2.900000e+01
# Number of Observations Used    8.730000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 7.494698233387084e-09 < 0.05
#
# Station:  3106
# Dickey-Fuller test:
#
# Test Statistic                -1.152080e+01
# p-value                        4.044668e-21
# #Lags Used                     2.600000e+01
# Number of Observations Used    8.733000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.04466828558108e-21 < 0.05
#
# Station:  3107
# Dickey-Fuller test:
#
# Test Statistic                -8.013817e+00
# p-value                        2.165604e-12
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.1656043158893443e-12 < 0.05
#
# Station:  3108
# Dickey-Fuller test:
#
# Test Statistic                -1.074566e+01
# p-value                        2.746118e-19
# #Lags Used                     2.600000e+01
# Number of Observations Used    8.733000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.7461179642589486e-19 < 0.05
#
# Station:  3109
# Dickey-Fuller test:
#
# Test Statistic                -6.486703e+00
# p-value                        1.255698e-08
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.2556975369425313e-08 < 0.05
#
# Station:  3110
# Dickey-Fuller test:
#
# Test Statistic                -9.964278e+00
# p-value                        2.329289e-17
# #Lags Used                     2.700000e+01
# Number of Observations Used    8.732000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.3292887813221437e-17 < 0.05
#
# Station:  3112
# Dickey-Fuller test:
#
# Test Statistic                -8.385208e+00
# p-value                        2.448941e-13
# #Lags Used                     3.200000e+01
# Number of Observations Used    8.727000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.448940930362605e-13 < 0.05
#
# Station:  3113
# Dickey-Fuller test:
#
# Test Statistic                -6.866426e+00
# p-value                        1.554911e-09
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.5549112388386547e-09 < 0.05
#
# Station:  3115
# Dickey-Fuller test:
#
# Test Statistic                -5.833177e+00
# p-value                        3.931547e-07
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.9315471352919224e-07 < 0.05
#
# Station:  3116
# Dickey-Fuller test:
#
# Test Statistic                -5.839337e+00
# p-value                        3.809894e-07
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.8098944445472267e-07 < 0.05
#
# Station:  3117
# Dickey-Fuller test:
#
# Test Statistic                -8.945766e+00
# p-value                        8.997833e-15
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 8.99783286167748e-15 < 0.05
#
# Station:  3118
# Dickey-Fuller test:
#
# Test Statistic                -8.127196e+00
# p-value                        1.114935e-12
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.1149354299715066e-12 < 0.05
#
# Station:  3119
# Dickey-Fuller test:
#
# Test Statistic                -9.523587e+00
# p-value                        3.019092e-16
# #Lags Used                     3.000000e+01
# Number of Observations Used    8.729000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.0190921471732945e-16 < 0.05
#
# Station:  3120
# Dickey-Fuller test:
#
# Test Statistic                -6.489458e+00
# p-value                        1.237067e-08
# #Lags Used                     2.400000e+01
# Number of Observations Used    8.735000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.237066936097979e-08 < 0.05
#
# Station:  3121
# Dickey-Fuller test:
#
# Test Statistic                -6.286945e+00
# p-value                        3.678293e-08
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.678292877973798e-08 < 0.05
#
# Station:  3122
# Dickey-Fuller test:
#
# Test Statistic                   -4.241128
# p-value                           0.000561
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.0005608773578654199 < 0.05
#
# Station:  3123
# Dickey-Fuller test:
#
# Test Statistic                   -5.235590
# p-value                           0.000007
# #Lags Used                       28.000000
# Number of Observations Used    8731.000000
# Critical Value (1%)              -3.431099
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 7.434308912076937e-06 < 0.05
#
# Station:  3124
# Dickey-Fuller test:
#
# Test Statistic                -9.457658e+00
# p-value                        4.440233e-16
# #Lags Used                     2.600000e+01
# Number of Observations Used    8.733000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.4402334030008457e-16 < 0.05
#
# Station:  3125
# Dickey-Fuller test:
#
# Test Statistic                -6.715031e+00
# p-value                        3.600023e-09
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.6000233649501873e-09 < 0.05
#
# Station:  3126
# Dickey-Fuller test:
#
# Test Statistic                -7.414452e+00
# p-value                        6.994859e-11
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 6.994858536092693e-11 < 0.05
#
# Station:  3127
# Dickey-Fuller test:
#
# Test Statistic                   -4.539917
# p-value                           0.000166
# #Lags Used                       29.000000
# Number of Observations Used    8730.000000
# Critical Value (1%)              -3.431099
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.00016643820197820405 < 0.05
#
# Station:  3128
# Dickey-Fuller test:
#
# Test Statistic                   -4.881991
# p-value                           0.000038
# #Lags Used                       26.000000
# Number of Observations Used    8733.000000
# Critical Value (1%)              -3.431099
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 3.7801231301229e-05 < 0.05
#
# Station:  3129
# Dickey-Fuller test:
#
# Test Statistic                -6.916142e+00
# p-value                        1.178135e-09
# #Lags Used                     2.600000e+01
# Number of Observations Used    8.733000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.1781349963522343e-09 < 0.05
#
# Station:  3130
# Dickey-Fuller test:
#
# Test Statistic                -7.254089e+00
# p-value                        1.749194e-10
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.7491943628800176e-10 < 0.05
#
# Station:  3131
# Dickey-Fuller test:
#
# Test Statistic                -1.184249e+01
# p-value                        7.532059e-22
# #Lags Used                     2.300000e+01
# Number of Observations Used    8.736000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 7.532058832558391e-22 < 0.05
#
# Station:  3132
# Dickey-Fuller test:
#
# Test Statistic                -1.172065e+01
# p-value                        1.416084e-21
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.4160837467870667e-21 < 0.05
#
# Station:  3134
# Dickey-Fuller test:
#
# Test Statistic                -7.775242e+00
# p-value                        8.704595e-12
# #Lags Used                     3.300000e+01
# Number of Observations Used    8.726000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 8.704594701594072e-12 < 0.05
#
# Station:  3135
# Dickey-Fuller test:
#
# Test Statistic                -5.955659e+00
# p-value                        2.096296e-07
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.0962962582856934e-07 < 0.05
#
# Station:  3136
# Dickey-Fuller test:
#
# Test Statistic                -7.480470e+00
# p-value                        4.787334e-11
# #Lags Used                     2.700000e+01
# Number of Observations Used    8.732000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.7873338129866936e-11 < 0.05
#
# Station:  3137
# Dickey-Fuller test:
#
# Test Statistic                -9.950014e+00
# p-value                        2.529337e-17
# #Lags Used                     2.700000e+01
# Number of Observations Used    8.732000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.5293368719819008e-17 < 0.05
#
# Station:  3139
# Dickey-Fuller test:
#
# Test Statistic                -8.333562e+00
# p-value                        3.318447e-13
# #Lags Used                     3.000000e+01
# Number of Observations Used    8.729000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.3184471869400473e-13 < 0.05
#
# Station:  3140
# Dickey-Fuller test:
#
# Test Statistic                -1.035565e+01
# p-value                        2.470723e-18
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.4707234468621356e-18 < 0.05
#
# Station:  3141
# Dickey-Fuller test:
#
# Test Statistic                -8.919974e+00
# p-value                        1.047508e-14
# #Lags Used                     2.800000e+01
# Number of Observations Used    8.731000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.047508287231169e-14 < 0.05
#
# Station:  3142
# Dickey-Fuller test:
#
# Test Statistic                -7.425768e+00
# p-value                        6.555158e-11
# #Lags Used                     3.000000e+01
# Number of Observations Used    8.729000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 6.555158396238165e-11 < 0.05
#
# Station:  3143
# Dickey-Fuller test:
#
# Test Statistic                -7.603987e+00
# p-value                        2.348622e-11
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.3486222570465537e-11 < 0.05
#
# Station:  3144
# Dickey-Fuller test:
#
# Test Statistic                -9.910224e+00
# p-value                        3.183610e-17
# #Lags Used                     2.700000e+01
# Number of Observations Used    8.732000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.1836099845727153e-17 < 0.05
#
# Station:  3145
# Dickey-Fuller test:
#
# Test Statistic                -8.840122e+00
# p-value                        1.677276e-14
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.723000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.6772761644599077e-14 < 0.05
#
# Station:  3146
# Dickey-Fuller test:
#
# Test Statistic                -1.045660e+01
# p-value                        1.393493e-18
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.3934929570117627e-18 < 0.05
#
# Station:  3147
# Dickey-Fuller test:
#
# Test Statistic                -9.481352e+00
# p-value                        3.865191e-16
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.8651914775837785e-16 < 0.05
#
# Station:  3148
# Dickey-Fuller test:
#
# Test Statistic                -1.114653e+01
# p-value                        3.016321e-20
# #Lags Used                     2.600000e+01
# Number of Observations Used    8.733000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.0163205294283936e-20 < 0.05
#
# Station:  3150
# Dickey-Fuller test:
#
# Test Statistic                -8.259154e+00
# p-value                        5.139230e-13
# #Lags Used                     3.300000e+01
# Number of Observations Used    8.726000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.13922968790776e-13 < 0.05
#
# Station:  3151
# Dickey-Fuller test:
#
# Test Statistic                -1.023633e+01
# p-value                        4.878417e-18
# #Lags Used                     2.700000e+01
# Number of Observations Used    8.732000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.878416505763776e-18 < 0.05
#
# Station:  3152
# Dickey-Fuller test:
#
# Test Statistic                -5.793359e+00
# p-value                        4.814663e-07
# #Lags Used                     2.300000e+01
# Number of Observations Used    8.736000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.814662880966869e-07 < 0.05
#
# Station:  3155
# Dickey-Fuller test:
#
# Test Statistic                   -5.178876
# p-value                           0.000010
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 9.708441896365961e-06 < 0.05
#
# Station:  3156
# Dickey-Fuller test:
#
# Test Statistic                -7.144386e+00
# p-value                        3.261324e-10
# #Lags Used                     2.800000e+01
# Number of Observations Used    8.731000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.261323580014293e-10 < 0.05
#
# Station:  3157
# Dickey-Fuller test:
#
# Test Statistic                -8.625813e+00
# p-value                        5.934802e-14
# #Lags Used                     2.900000e+01
# Number of Observations Used    8.730000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.934802450125286e-14 < 0.05
#
# Station:  3158
# Dickey-Fuller test:
#
# Test Statistic                -1.132898e+01
# p-value                        1.124971e-20
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.1249714354635378e-20 < 0.05
#
# Station:  3159
# Dickey-Fuller test:
#
# Test Statistic                -9.813761e+00
# p-value                        5.567605e-17
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.567605247141001e-17 < 0.05
#
# Station:  3160
# Dickey-Fuller test:
#
# Test Statistic                -6.958303e+00
# p-value                        9.304880e-10
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 9.304880291877907e-10 < 0.05
#
# Station:  3161
# Dickey-Fuller test:
#
# Test Statistic                -1.006535e+01
# p-value                        1.300699e-17
# #Lags Used                     2.600000e+01
# Number of Observations Used    8.733000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.3006991774690492e-17 < 0.05
#
# Station:  3162
# Dickey-Fuller test:
#
# Test Statistic                -1.131367e+01
# p-value                        1.221460e-20
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.221459562023166e-20 < 0.05
#
# Station:  3163
# Dickey-Fuller test:
#
# Test Statistic                -7.875187e+00
# p-value                        4.865348e-12
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.8653481534427885e-12 < 0.05
#
# Station:  3164
# Dickey-Fuller test:
#
# Test Statistic                -1.125156e+01
# p-value                        1.707051e-20
# #Lags Used                     3.000000e+01
# Number of Observations Used    8.729000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.7070505954134516e-20 < 0.05
#
# Station:  3165
# Dickey-Fuller test:
#
# Test Statistic                -7.158275e+00
# p-value                        3.014554e-10
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.0145541585230897e-10 < 0.05
#
# Station:  3166
# Dickey-Fuller test:
#
# Test Statistic                -1.042865e+01
# p-value                        1.632450e-18
# #Lags Used                     2.600000e+01
# Number of Observations Used    8.733000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.632449690351281e-18 < 0.05
#
# Station:  3167
# Dickey-Fuller test:
#
# Test Statistic                -1.036457e+01
# p-value                        2.348617e-18
# #Lags Used                     2.800000e+01
# Number of Observations Used    8.731000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.3486174362126563e-18 < 0.05
#
# Station:  3168
# Dickey-Fuller test:
#
# Test Statistic                -9.858736e+00
# p-value                        4.289405e-17
# #Lags Used                     2.600000e+01
# Number of Observations Used    8.733000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.2894048655109256e-17 < 0.05
#
# Station:  3169
# Dickey-Fuller test:
#
# Test Statistic                -8.388636e+00
# p-value                        2.400023e-13
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.400023456337564e-13 < 0.05
#
# Station:  3170
# Dickey-Fuller test:
#
# Test Statistic                -1.018784e+01
# p-value                        6.438033e-18
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 6.4380331210986716e-18 < 0.05
#
# Station:  3171
# Dickey-Fuller test:
#
# Test Statistic                -1.034295e+01
# p-value                        2.655740e-18
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.655740345236708e-18 < 0.05
#
# Station:  3172
# Dickey-Fuller test:
#
# Test Statistic                -7.596905e+00
# p-value                        2.446725e-11
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.4467254390138316e-11 < 0.05
#
# Station:  3173
# Dickey-Fuller test:
#
# Test Statistic                -1.155556e+01
# p-value                        3.365766e-21
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.723000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.365765929176616e-21 < 0.05
#
# Station:  3175
# Dickey-Fuller test:
#
# Test Statistic                -7.952061e+00
# p-value                        3.106911e-12
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.723000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.1069114531199695e-12 < 0.05
#
# Station:  3176
# Dickey-Fuller test:
#
# Test Statistic                -5.791983e+00
# p-value                        4.848416e-07
# #Lags Used                     3.200000e+01
# Number of Observations Used    8.727000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.848415509835508e-07 < 0.05
#
# Station:  3177
# Dickey-Fuller test:
#
# Test Statistic                -9.610453e+00
# p-value                        1.817684e-16
# #Lags Used                     2.600000e+01
# Number of Observations Used    8.733000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.8176842960284944e-16 < 0.05
#
# Station:  3178
# Dickey-Fuller test:
#
# Test Statistic                -8.008047e+00
# p-value                        2.239927e-12
# #Lags Used                     2.900000e+01
# Number of Observations Used    8.730000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.2399274172823926e-12 < 0.05
#
# Station:  3179
# Dickey-Fuller test:
#
# Test Statistic                   -5.327414
# p-value                           0.000005
# #Lags Used                       36.000000
# Number of Observations Used    8723.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 4.803314067636644e-06 < 0.05
#
# Station:  3180
# Dickey-Fuller test:
#
# Test Statistic                   -4.762634
# p-value                           0.000064
# #Lags Used                       25.000000
# Number of Observations Used    8734.000000
# Critical Value (1%)              -3.431099
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 6.408094207864321e-05 < 0.05
#
# Station:  3183
# Dickey-Fuller test:
#
# Test Statistic                -9.695466e+00
# p-value                        1.107408e-16
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.723000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.1074082057798761e-16 < 0.05
#
# Station:  3184
# Dickey-Fuller test:
#
# Test Statistic                -1.195900e+01
# p-value                        4.144620e-22
# #Lags Used                     3.500000e+01
# ...
#
# Stationary: p-value 1.988080767980646e-20 < 0.05
#
# Station:  3430
# Dickey-Fuller test:
#
# Test Statistic                -9.513583e+00
# p-value                        3.200981e-16
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.723000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.200981209229934e-16 < 0.05
#
# Station:  3431
# Dickey-Fuller test:
#
# Test Statistic                -1.039084e+01
# p-value                        2.022937e-18
# #Lags Used                     3.300000e+01
# Number of Observations Used    8.726000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.0229371226719598e-18 < 0.05
#
# Station:  3434
# Dickey-Fuller test:
#
# Test Statistic                -7.963732e+00
# p-value                        2.902169e-12
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.902168725711227e-12 < 0.05
#
# Station:  3435
# Dickey-Fuller test:
#
# Test Statistic                -8.365858e+00
# p-value                        2.744279e-13
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.723000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.7442792654974917e-13 < 0.05
#
# Station:  3436
# Dickey-Fuller test:
#
# Test Statistic                         NaN
# p-value                                NaN
# #Lags Used                        0.000000
# Number of Observations Used    8759.000000
# Critical Value (1%)              -3.431097
# Critical Value (5%)              -2.861870
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Not Stationary: p-value nan > 0.05
#
# Station:  3437
# Dickey-Fuller test:
#
# Test Statistic                -9.967019e+00
# p-value                        2.292706e-17
# #Lags Used                     2.500000e+01
# Number of Observations Used    8.734000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.2927059419753182e-17 < 0.05
#
# Station:  3438
# Dickey-Fuller test:
#
# Test Statistic                   -5.624465
# p-value                           0.000001
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 1.1256229354706913e-06 < 0.05
#
# Station:  3440
# Dickey-Fuller test:
#
# Test Statistic                -1.076242e+01
# p-value                        2.501175e-19
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.501175328548303e-19 < 0.05
#
# Station:  3443
# Dickey-Fuller test:
#
# Test Statistic                -9.318944e+00
# p-value                        1.001352e-15
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.0013517851157368e-15 < 0.05
#
# Station:  3447
# Dickey-Fuller test:
#
# Test Statistic                   -5.167914
# p-value                           0.000010
# #Lags Used                       29.000000
# Number of Observations Used    8730.000000
# Critical Value (1%)              -3.431099
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 1.0219784037089809e-05 < 0.05
#
# Station:  3449
# Dickey-Fuller test:
#
# Test Statistic                -8.907453e+00
# p-value                        1.127750e-14
# #Lags Used                     3.300000e+01
# Number of Observations Used    8.726000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.1277495765903204e-14 < 0.05
#
# Station:  3452
# Dickey-Fuller test:
#
# Test Statistic                -5.916276e+00
# p-value                        2.568382e-07
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.723000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.5683823594012914e-07 < 0.05
#
# Station:  3453
# Dickey-Fuller test:
#
# Test Statistic                -8.097671e+00
# p-value                        1.325554e-12
# #Lags Used                     2.400000e+01
# Number of Observations Used    8.735000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.3255538269001348e-12 < 0.05
#
# Station:  3454
# Dickey-Fuller test:
#
# Test Statistic                -6.256069e+00
# p-value                        4.335946e-08
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.335945622602939e-08 < 0.05
#
# Station:  3455
# Dickey-Fuller test:
#
# Test Statistic                   -3.150699
# p-value                           0.023022
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.023021730010733727 < 0.05
#
# Station:  3456
# Dickey-Fuller test:
#
# Test Statistic                -7.662775e+00
# p-value                        1.671542e-11
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.671541867092881e-11 < 0.05
#
# Station:  3457
# Dickey-Fuller test:
#
# Test Statistic                -9.829332e+00
# p-value                        5.086673e-17
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.08667321167273e-17 < 0.05
#
# Station:  3458
# Dickey-Fuller test:
#
# Test Statistic                -9.824527e+00
# p-value                        5.230457e-17
# #Lags Used                     2.900000e+01
# Number of Observations Used    8.730000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.230456939529166e-17 < 0.05
#
# Station:  3459
# Dickey-Fuller test:
#
# Test Statistic                -1.028317e+01
# p-value                        3.733361e-18
# #Lags Used                     3.000000e+01
# Number of Observations Used    8.729000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.7333613360261535e-18 < 0.05
#
# Station:  3461
# Dickey-Fuller test:
#
# Test Statistic                -1.041631e+01
# p-value                        1.750792e-18
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.7507923416450277e-18 < 0.05
#
# Station:  3462
# Dickey-Fuller test:
#
# Test Statistic                -9.869193e+00
# p-value                        4.037236e-17
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.037235759340811e-17 < 0.05
#
# Station:  3463
# Dickey-Fuller test:
#
# Test Statistic                -5.837282e+00
# p-value                        3.850063e-07
# #Lags Used                     3.500000e+01
# Number of Observations Used    8.724000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.8500626301622267e-07 < 0.05
#
# Station:  3466
# Dickey-Fuller test:
#
# Test Statistic                -1.108167e+01
# p-value                        4.295993e-20
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.2959934551683553e-20 < 0.05
#
# Station:  3467
# Dickey-Fuller test:
#
# Test Statistic                -6.627567e+00
# p-value                        5.824082e-09
# #Lags Used                     2.800000e+01
# Number of Observations Used    8.731000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 5.824081623953252e-09 < 0.05
#
# Station:  3469
# Dickey-Fuller test:
#
# Test Statistic                -6.461553e+00
# p-value                        1.439044e-08
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.439044154440022e-08 < 0.05
#
# Station:  3472
# Dickey-Fuller test:
#
# Test Statistic                -9.148423e+00
# p-value                        2.727815e-15
# #Lags Used                     3.200000e+01
# Number of Observations Used    8.727000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 2.7278152813408276e-15 < 0.05
#
# Station:  3474
# Dickey-Fuller test:
#
# Test Statistic                -9.777712e+00
# p-value                        6.863865e-17
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 6.863865470795506e-17 < 0.05
#
# Station:  3476
# Dickey-Fuller test:
#
# Test Statistic                         NaN
# p-value                                NaN
# #Lags Used                        0.000000
# Number of Observations Used    8759.000000
# Critical Value (1%)              -3.431097
# Critical Value (5%)              -2.861870
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Not Stationary: p-value nan > 0.05
#
# Station:  3477
# Dickey-Fuller test:
#
# Test Statistic                -7.902912e+00
# p-value                        4.139109e-12
# #Lags Used                     2.600000e+01
# Number of Observations Used    8.733000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.1391093490676206e-12 < 0.05
#
# Station:  3478
# Dickey-Fuller test:
#
# Test Statistic                -9.449882e+00
# p-value                        4.647078e-16
# #Lags Used                     3.400000e+01
# Number of Observations Used    8.725000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.64707847199801e-16 < 0.05
#
# Station:  3481
# Dickey-Fuller test:
#
# Test Statistic                -7.069897e+00
# p-value                        4.968498e-10
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.96849817005351e-10 < 0.05
#
# Station:  3486
# Dickey-Fuller test:
#
# Test Statistic                -9.858379e+00
# p-value                        4.298302e-17
# #Lags Used                     3.000000e+01
# Number of Observations Used    8.729000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 4.2983020604200144e-17 < 0.05
#
# Station:  3489
# Dickey-Fuller test:
#
# Test Statistic                -7.701699e+00
# p-value                        1.334014e-11
# #Lags Used                     2.700000e+01
# Number of Observations Used    8.732000e+03
# Critical Value (1%)           -3.431099e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 1.3340137418561236e-11 < 0.05
#
# Station:  3490
# Dickey-Fuller test:
#
# Test Statistic                   -4.143089
# p-value                           0.000821
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.000821326001831637 < 0.05
#
# Station:  3491
# Dickey-Fuller test:
#
# Test Statistic                   -4.522743
# p-value                           0.000179
# #Lags Used                       34.000000
# Number of Observations Used    8725.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.000178847145561195 < 0.05
#
# Station:  3492
# Dickey-Fuller test:
#
# Test Statistic                   -3.475295
# p-value                           0.008645
# #Lags Used                       18.000000
# Number of Observations Used    8741.000000
# Critical Value (1%)              -3.431098
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.008644717598708995 < 0.05
#
# Station:  3493
# Dickey-Fuller test:
#
# Test Statistic                -5.835286e+00
# p-value                        3.889469e-07
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.722000e+03
# Critical Value (1%)           -3.431100e+00
# Critical Value (5%)           -2.861871e+00
# Critical Value (10%)          -2.566946e+00
# dtype: float64
#
# Stationary: p-value 3.889469289324798e-07 < 0.05
#
# Station:  3494
# Dickey-Fuller test:
#
# Test Statistic                   -4.362135
# p-value                           0.000346
# #Lags Used                       30.000000
# Number of Observations Used    8729.000000
# Critical Value (1%)              -3.431099
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 0.0003461402735158807 < 0.05
#
# Station:  3495
# Dickey-Fuller test:
#
# Test Statistic                   -5.005250
# p-value                           0.000022
# #Lags Used                       37.000000
# Number of Observations Used    8722.000000
# Critical Value (1%)              -3.431100
# Critical Value (5%)              -2.861871
# Critical Value (10%)             -2.566946
# dtype: float64
#
# Stationary: p-value 2.1668305144879132e-05 < 0.05

# %%
dickey_results.value_counts()
# Out:
# True     656
# False      8
# dtype: int64

# %%
investigate = dickey_results.loc[dickey_results == False]
len(investigate)
# Out:
# 8

# %%
fig, ax = plt.subplots(ncols=4,nrows=2,figsize=(20,5))

for i, ts in enumerate(investigate.index):
  ax[i//4][i%4].plot(station_mat[ts])
  ax[i//4][i%4].set_title(f'Station: {ts}')

# %%
station_mat.drop(columns=investigate.index,inplace=True)
station_mat.head()
# Out:
#                        72   79   82    83   119  ...  3491  3492  3493  3494  3495
# date_time                                        ...
# 2018-01-01 00:00:00  13.0  4.0  3.0  30.0  12.0  ...  13.0  16.0  11.0  17.0  20.0
# 2018-01-01 01:00:00  13.0  4.0  4.0  30.0  12.0  ...  13.0  16.0  11.0  17.0  20.0
# 2018-01-01 02:00:00  13.0  4.0  4.0  30.0  12.0  ...  13.0  16.0  11.0  17.0  20.0
# 2018-01-01 03:00:00  13.0  4.0  4.0  30.0  12.0  ...  13.0  16.0  11.5  17.0  20.0
# 2018-01-01 04:00:00  13.0  4.0  4.0  30.0  12.0  ...  13.0  16.0  12.0  17.0  20.0
#
# [5 rows x 656 columns]

# %%
import pickle

# %%
pickle_out = open('station_mat.pickle','wb')
pickle.dump(station_mat,pickle_out)
pickle_out.close()

# %%
station_mat = pickle.load(open('/content/station_mat.pickle','rb'))

# %%
from statsmodels.tsa.vector_ar.var_model import VAR
from statsmodels.tools.eval_measures import rmse, aic, meanabs
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
var_model = VAR(station_mat)
var_results = {'p':[],'aic':[]}

for p in range(7):  
  result = var_model.fit(p, ic='aic')
  var_results['p'].append(p)
  var_results['aic'].append(result.aic)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/var_model.py:2092: RuntimeWarning:
#
# overflow encountered in exp

# %%
var_results
# Out:
# {'aic': [1685.289177831974,
#   682.2091136089293,
#   665.6892406075153,
#   652.9762575419118,
#   634.6438200808111,
#   606.0201182650333,
#   559.21803589028],
#  'p': [0, 1, 2, 3, 4, 5, 6]}

# %%
var_model = VAR(station_mat)
result = var_model.fit(6, ic='aic')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/var_model.py:2092: RuntimeWarning:
#
# overflow encountered in exp

# %%
station_mat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-11dbe6890831> in <module>()
# ----> 1 station_mat
#
# NameError: name 'station_mat' is not defined
